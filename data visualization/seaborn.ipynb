# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#countplot : survival based on gender 
sns.countplot(df, x='survived', )
plt.title('survived vs not survive by gender')
plt.show()

# %%
sns.barplot(df, x='sex', y='fare',)
plt.title('average fare by passenger')
# Out:
# Text(0.5, 1.0, 'average fare by passenger')

# %%
sns.pointplot(df, x='class', y='survival by gender')
plt.title('survival rate by class')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sns.pointplot(df, x='class', y='survival by gender')
#       2 plt.title('survival rate by class')
#       3 plt.show()
#
# File c:\Users\Hp\miniconda3\lib\site-packages\seaborn\categorical.py:2479, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, color, palette, hue_norm, markers, linestyles, dodge, log_scale, native_scale, orient, capsize, formatter, legend, err_kws, ci, errwidth, join, scale, ax, **kwargs)
#    2467 def pointplot(
#    2468     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2469     estimator="mean", errorbar=("ci", 95), n_boot=1000, seed=None, units=None,
#    (...)
#    2474     ax=None, **kwargs,
#    2475 ):
#    2477     errorbar = utils._deprecate_ci(errorbar, ci)
# ...
